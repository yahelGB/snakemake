# %%
# libraries import
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import defaultdict

# %%
# read gff file and data structuring
contigs = {}

with open('GCF_003789085.1_ASM378908v1_genomic.gff', 'r') as f_input:
    for line in f_input:
        if line.startswith('#') or not line.strip():
            continue

        parts = line.strip().split('\t')

        contig_id = parts[0]
        feature_type = parts[2]
        start = int(parts[3])
        end = int(parts[4])
        strand = parts[6]
        metadata = parts[8]
        metadata_split = metadata.split(';')
        metadata_dict = {item.split('=')[0]: item.split('=')[1] for item in metadata_split if '=' in item}

        feature = {
            'type': feature_type,
            'start': start,
            'end': end,
            'strand': strand,
            'metadata': metadata_dict,
        }

        if contig_id not in contigs:
            contigs[contig_id] = []
        contigs[contig_id].append(feature)

# check for data structure (not necessary)
# for contig_id, features in contigs.items():
#     print(f"Contig: {contig_id}, Number of features: {len(features)}")
#     for feature in features[:5]:  # display the first 5 features of each contig
#         print(feature)
#     print()

# %%
# count the long non-coding RNAs in each contig 
lncRNA_count_per_contig = defaultdict(set)

for contig_id, features in contigs.items():
    for feature in features:
        if feature['type'] == 'lnc_RNA':
            # Use the unique ID directly to count lncRNAs
            gene_id = feature['metadata'].get('ID', 'Unknown')
            if gene_id != 'Unknown':
                lncRNA_count_per_contig[contig_id].add(gene_id)

# Display the number of long non-coding RNAs per contig
total_lncRNAs = sum(len(lncRNAs) for lncRNAs in lncRNA_count_per_contig.values())
print(f"Total long non-coding RNAs: {total_lncRNAs}")
for contig_id, lncRNAs in lncRNA_count_per_contig.items():
    print(f"Contig: {contig_id}, Number of unique lncRNAs: {len(lncRNAs)}")

# Verify if the total matches the expected 2,028
if total_lncRNAs == 2028:
    print("The total number of long non-coding RNAs matches the expected: 2,028")
else:
    print(f"The total number of long non-coding RNAs ({total_lncRNAs}) does not match the expected: 2,028")
# Out:
# Total long non-coding RNAs: 2028
# Contig: NW_020868287.1, Number of unique lncRNAs: 1
# Contig: NW_020868290.1, Number of unique lncRNAs: 6
# Contig: NW_020868291.1, Number of unique lncRNAs: 1
# Contig: NW_020868292.1, Number of unique lncRNAs: 7
# Contig: NW_020868300.1, Number of unique lncRNAs: 1
# Contig: NW_020868305.1, Number of unique lncRNAs: 1
# Contig: NW_020868307.1, Number of unique lncRNAs: 16
# Contig: NW_020868311.1, Number of unique lncRNAs: 2
# Contig: NW_020868314.1, Number of unique lncRNAs: 1
# Contig: NW_020868326.1, Number of unique lncRNAs: 2
# Contig: NW_020868327.1, Number of unique lncRNAs: 1
# Contig: NW_020868328.1, Number of unique lncRNAs: 1
# Contig: NW_020868329.1, Number of unique lncRNAs: 3
# Contig: NW_020868337.1, Number of unique lncRNAs: 1
# Contig: NW_020868347.1, Number of unique lncRNAs: 4
# Contig: NW_020868350.1, Number of unique lncRNAs: 1
# Contig: NW_020868353.1, Number of unique lncRNAs: 2
# Contig: NW_020868355.1, Number of unique lncRNAs: 1
# Contig: NW_020868364.1, Number of unique lncRNAs: 1
# Contig: NW_020868366.1, Number of unique lncRNAs: 2
# Contig: NW_020868368.1, Number of unique lncRNAs: 2
# Contig: NW_020868370.1, Number of unique lncRNAs: 2
# Contig: NW_020868375.1, Number of unique lncRNAs: 3
# Contig: NW_020868386.1, Number of unique lncRNAs: 1
# Contig: NW_020868387.1, Number of unique lncRNAs: 1
# Contig: NW_020868392.1, Number of unique lncRNAs: 1
# Contig: NW_020868393.1, Number of unique lncRNAs: 1
# Contig: NW_020868395.1, Number of unique lncRNAs: 2
# Contig: NW_020868397.1, Number of unique lncRNAs: 1
# Contig: NW_020868402.1, Number of unique lncRNAs: 1
# Contig: NW_020868415.1, Number of unique lncRNAs: 2
# Contig: NW_020868417.1, Number of unique lncRNAs: 1
# Contig: NW_020868425.1, Number of unique lncRNAs: 1
# Contig: NW_020868426.1, Number of unique lncRNAs: 2
# Contig: NW_020868427.1, Number of unique lncRNAs: 2
# Contig: NW_020868429.1, Number of unique lncRNAs: 1
# Contig: NW_020868431.1, Number of unique lncRNAs: 1
# Contig: NW_020868433.1, Number of unique lncRNAs: 1
# Contig: NW_020868439.1, Number of unique lncRNAs: 2
# Contig: NW_020868441.1, Number of unique lncRNAs: 2
# Contig: NW_020868442.1, Number of unique lncRNAs: 2
# Contig: NW_020868443.1, Number of unique lncRNAs: 1
# Contig: NW_020868444.1, Number of unique lncRNAs: 3
# Contig: NW_020868447.1, Number of unique lncRNAs: 4
# Contig: NW_020868448.1, Number of unique lncRNAs: 1
# Contig: NW_020868449.1, Number of unique lncRNAs: 2
# Contig: NW_020868450.1, Number of unique lncRNAs: 3
# Contig: NW_020868451.1, Number of unique lncRNAs: 1
# Contig: NW_020868453.1, Number of unique lncRNAs: 1
# Contig: NW_020868455.1, Number of unique lncRNAs: 2
# Contig: NW_020868458.1, Number of unique lncRNAs: 2
# Contig: NW_020868469.1, Number of unique lncRNAs: 13
# Contig: NW_020868474.1, Number of unique lncRNAs: 3
# Contig: NW_020868475.1, Number of unique lncRNAs: 1
# Contig: NW_020868477.1, Number of unique lncRNAs: 3
# Contig: NW_020868483.1, Number of unique lncRNAs: 1
# Contig: NW_020868484.1, Number of unique lncRNAs: 2
# Contig: NW_020868485.1, Number of unique lncRNAs: 1
# Contig: NW_020868493.1, Number of unique lncRNAs: 1
# Contig: NW_020868494.1, Number of unique lncRNAs: 2
# Contig: NW_020868497.1, Number of unique lncRNAs: 1
# Contig: NW_020868511.1, Number of unique lncRNAs: 1
# Contig: NW_020868516.1, Number of unique lncRNAs: 1
# Contig: NW_020868517.1, Number of unique lncRNAs: 11
# Contig: NW_020868523.1, Number of unique lncRNAs: 1
# Contig: NW_020868524.1, Number of unique lncRNAs: 1
# Contig: NW_020868525.1, Number of unique lncRNAs: 2
# Contig: NW_020868536.1, Number of unique lncRNAs: 2
# Contig: NW_020868539.1, Number of unique lncRNAs: 1
# Contig: NW_020868542.1, Number of unique lncRNAs: 1
# Contig: NW_020868548.1, Number of unique lncRNAs: 1
# Contig: NW_020868557.1, Number of unique lncRNAs: 1
# Contig: NW_020868567.1, Number of unique lncRNAs: 2
# Contig: NW_020868569.1, Number of unique lncRNAs: 1
# Contig: NW_020868570.1, Number of unique lncRNAs: 1
# Contig: NW_020868581.1, Number of unique lncRNAs: 6
# Contig: NW_020868582.1, Number of unique lncRNAs: 2
# Contig: NW_020868588.1, Number of unique lncRNAs: 1
# Contig: NW_020868589.1, Number of unique lncRNAs: 1
# Contig: NW_020868594.1, Number of unique lncRNAs: 1
# Contig: NW_020868599.1, Number of unique lncRNAs: 1
# Contig: NW_020868602.1, Number of unique lncRNAs: 4
# Contig: NW_020868607.1, Number of unique lncRNAs: 4
# Contig: NW_020868608.1, Number of unique lncRNAs: 1
# Contig: NW_020868616.1, Number of unique lncRNAs: 1
# Contig: NW_020868624.1, Number of unique lncRNAs: 1
# Contig: NW_020868625.1, Number of unique lncRNAs: 1
# Contig: NW_020868628.1, Number of unique lncRNAs: 1
# Contig: NW_020868636.1, Number of unique lncRNAs: 1
# Contig: NW_020868637.1, Number of unique lncRNAs: 6
# Contig: NW_020868639.1, Number of unique lncRNAs: 1
# Contig: NW_020868640.1, Number of unique lncRNAs: 3
# Contig: NW_020868652.1, Number of unique lncRNAs: 1
# Contig: NW_020868657.1, Number of unique lncRNAs: 2
# Contig: NW_020868661.1, Number of unique lncRNAs: 2
# Contig: NW_020868662.1, Number of unique lncRNAs: 2
# Contig: NW_020868666.1, Number of unique lncRNAs: 1
# Contig: NW_020868672.1, Number of unique lncRNAs: 3
# Contig: NW_020868673.1, Number of unique lncRNAs: 1
# Contig: NW_020868675.1, Number of unique lncRNAs: 2
# Contig: NW_020868678.1, Number of unique lncRNAs: 2
# Contig: NW_020868684.1, Number of unique lncRNAs: 1
# Contig: NW_020868690.1, Number of unique lncRNAs: 1
# Contig: NW_020868695.1, Number of unique lncRNAs: 2
# Contig: NW_020868696.1, Number of unique lncRNAs: 3
# Contig: NW_020868707.1, Number of unique lncRNAs: 1
# Contig: NW_020868708.1, Number of unique lncRNAs: 1
# Contig: NW_020868710.1, Number of unique lncRNAs: 1
# Contig: NW_020868714.1, Number of unique lncRNAs: 1
# Contig: NW_020868717.1, Number of unique lncRNAs: 1
# Contig: NW_020868718.1, Number of unique lncRNAs: 2
# Contig: NW_020868731.1, Number of unique lncRNAs: 1
# Contig: NW_020868735.1, Number of unique lncRNAs: 1
# Contig: NW_020868737.1, Number of unique lncRNAs: 5
# Contig: NW_020868745.1, Number of unique lncRNAs: 1
# Contig: NW_020868751.1, Number of unique lncRNAs: 3
# Contig: NW_020868760.1, Number of unique lncRNAs: 1
# Contig: NW_020868762.1, Number of unique lncRNAs: 3
# Contig: NW_020868763.1, Number of unique lncRNAs: 2
# Contig: NW_020868764.1, Number of unique lncRNAs: 1
# Contig: NW_020868767.1, Number of unique lncRNAs: 7
# Contig: NW_020868772.1, Number of unique lncRNAs: 1
# Contig: NW_020868774.1, Number of unique lncRNAs: 1
# Contig: NW_020868775.1, Number of unique lncRNAs: 1
# Contig: NW_020868776.1, Number of unique lncRNAs: 1
# Contig: NW_020868780.1, Number of unique lncRNAs: 3
# Contig: NW_020868786.1, Number of unique lncRNAs: 2
# Contig: NW_020868788.1, Number of unique lncRNAs: 1
# Contig: NW_020868792.1, Number of unique lncRNAs: 2
# Contig: NW_020868793.1, Number of unique lncRNAs: 3
# Contig: NW_020868796.1, Number of unique lncRNAs: 1
# Contig: NW_020868800.1, Number of unique lncRNAs: 1
# Contig: NW_020868801.1, Number of unique lncRNAs: 1
# Contig: NW_020868803.1, Number of unique lncRNAs: 2
# Contig: NW_020868805.1, Number of unique lncRNAs: 1
# Contig: NW_020868812.1, Number of unique lncRNAs: 1
# Contig: NW_020868820.1, Number of unique lncRNAs: 1
# Contig: NW_020868825.1, Number of unique lncRNAs: 1
# Contig: NW_020868826.1, Number of unique lncRNAs: 2
# Contig: NW_020868833.1, Number of unique lncRNAs: 1
# Contig: NW_020868835.1, Number of unique lncRNAs: 1
# Contig: NW_020868840.1, Number of unique lncRNAs: 1
# Contig: NW_020868851.1, Number of unique lncRNAs: 1
# Contig: NW_020868854.1, Number of unique lncRNAs: 1
# Contig: NW_020868855.1, Number of unique lncRNAs: 1
# Contig: NW_020868857.1, Number of unique lncRNAs: 3
# Contig: NW_020868860.1, Number of unique lncRNAs: 1
# Contig: NW_020868861.1, Number of unique lncRNAs: 1
# Contig: NW_020868864.1, Number of unique lncRNAs: 1
# Contig: NW_020868865.1, Number of unique lncRNAs: 1
# Contig: NW_020868866.1, Number of unique lncRNAs: 2
# Contig: NW_020868868.1, Number of unique lncRNAs: 3
# Contig: NW_020868882.1, Number of unique lncRNAs: 1
# Contig: NW_020868883.1, Number of unique lncRNAs: 1
# Contig: NW_020868886.1, Number of unique lncRNAs: 1
# Contig: NW_020868887.1, Number of unique lncRNAs: 2
# Contig: NW_020868892.1, Number of unique lncRNAs: 2
# Contig: NW_020868894.1, Number of unique lncRNAs: 1
# Contig: NW_020868904.1, Number of unique lncRNAs: 3
# Contig: NW_020868907.1, Number of unique lncRNAs: 1
# Contig: NW_020868911.1, Number of unique lncRNAs: 1
# Contig: NW_020868913.1, Number of unique lncRNAs: 6
# Contig: NW_020868918.1, Number of unique lncRNAs: 1
# Contig: NW_020868919.1, Number of unique lncRNAs: 2
# Contig: NW_020868920.1, Number of unique lncRNAs: 1
# Contig: NW_020868923.1, Number of unique lncRNAs: 1
# Contig: NW_020868927.1, Number of unique lncRNAs: 1
# Contig: NW_020868930.1, Number of unique lncRNAs: 1
# Contig: NW_020868932.1, Number of unique lncRNAs: 1
# Contig: NW_020868936.1, Number of unique lncRNAs: 7
# Contig: NW_020868938.1, Number of unique lncRNAs: 2
# Contig: NW_020868939.1, Number of unique lncRNAs: 1
# Contig: NW_020868946.1, Number of unique lncRNAs: 1
# Contig: NW_020868947.1, Number of unique lncRNAs: 1
# Contig: NW_020868949.1, Number of unique lncRNAs: 2
# Contig: NW_020868952.1, Number of unique lncRNAs: 1
# Contig: NW_020868959.1, Number of unique lncRNAs: 1
# Contig: NW_020868965.1, Number of unique lncRNAs: 1
# Contig: NW_020868970.1, Number of unique lncRNAs: 1
# Contig: NW_020868972.1, Number of unique lncRNAs: 2
# Contig: NW_020868973.1, Number of unique lncRNAs: 3
# Contig: NW_020868974.1, Number of unique lncRNAs: 1
# Contig: NW_020868980.1, Number of unique lncRNAs: 1
# Contig: NW_020868981.1, Number of unique lncRNAs: 3
# Contig: NW_020868990.1, Number of unique lncRNAs: 1
# Contig: NW_020868991.1, Number of unique lncRNAs: 2
# Contig: NW_020868993.1, Number of unique lncRNAs: 1
# Contig: NW_020868994.1, Number of unique lncRNAs: 1
# Contig: NW_020868998.1, Number of unique lncRNAs: 1
# Contig: NW_020869003.1, Number of unique lncRNAs: 3
# Contig: NW_020869005.1, Number of unique lncRNAs: 1
# Contig: NW_020869006.1, Number of unique lncRNAs: 2
# Contig: NW_020869007.1, Number of unique lncRNAs: 1
# Contig: NW_020869014.1, Number of unique lncRNAs: 2
# Contig: NW_020869017.1, Number of unique lncRNAs: 1
# Contig: NW_020869021.1, Number of unique lncRNAs: 1
# Contig: NW_020869026.1, Number of unique lncRNAs: 1
# Contig: NW_020869028.1, Number of unique lncRNAs: 2
# Contig: NW_020869029.1, Number of unique lncRNAs: 3
# Contig: NW_020869032.1, Number of unique lncRNAs: 2
# Contig: NW_020869035.1, Number of unique lncRNAs: 10
# Contig: NW_020869036.1, Number of unique lncRNAs: 2
# Contig: NW_020869040.1, Number of unique lncRNAs: 3
# Contig: NW_020869041.1, Number of unique lncRNAs: 3
# Contig: NW_020869047.1, Number of unique lncRNAs: 6
# Contig: NW_020869050.1, Number of unique lncRNAs: 6
# Contig: NW_020869055.1, Number of unique lncRNAs: 1
# Contig: NW_020869060.1, Number of unique lncRNAs: 1
# Contig: NW_020869061.1, Number of unique lncRNAs: 2
# Contig: NW_020869062.1, Number of unique lncRNAs: 1
# Contig: NW_020869065.1, Number of unique lncRNAs: 3
# Contig: NW_020869077.1, Number of unique lncRNAs: 3
# Contig: NW_020869078.1, Number of unique lncRNAs: 7
# Contig: NW_020869079.1, Number of unique lncRNAs: 6
# Contig: NW_020869084.1, Number of unique lncRNAs: 2
# Contig: NW_020869088.1, Number of unique lncRNAs: 1
# Contig: NW_020869091.1, Number of unique lncRNAs: 1
# Contig: NW_020869093.1, Number of unique lncRNAs: 1
# Contig: NW_020869103.1, Number of unique lncRNAs: 1
# Contig: NW_020869107.1, Number of unique lncRNAs: 3
# Contig: NW_020869108.1, Number of unique lncRNAs: 3
# Contig: NW_020869112.1, Number of unique lncRNAs: 1
# Contig: NW_020869114.1, Number of unique lncRNAs: 1
# Contig: NW_020869115.1, Number of unique lncRNAs: 2
# Contig: NW_020869116.1, Number of unique lncRNAs: 2
# Contig: NW_020869118.1, Number of unique lncRNAs: 1
# Contig: NW_020869121.1, Number of unique lncRNAs: 2
# Contig: NW_020869124.1, Number of unique lncRNAs: 1
# Contig: NW_020869126.1, Number of unique lncRNAs: 1
# Contig: NW_020869128.1, Number of unique lncRNAs: 1
# Contig: NW_020869130.1, Number of unique lncRNAs: 1
# Contig: NW_020869132.1, Number of unique lncRNAs: 1
# Contig: NW_020869133.1, Number of unique lncRNAs: 12
# Contig: NW_020869137.1, Number of unique lncRNAs: 1
# Contig: NW_020869140.1, Number of unique lncRNAs: 1
# Contig: NW_020869147.1, Number of unique lncRNAs: 2
# Contig: NW_020869148.1, Number of unique lncRNAs: 1
# Contig: NW_020869151.1, Number of unique lncRNAs: 1
# Contig: NW_020869155.1, Number of unique lncRNAs: 1
# Contig: NW_020869159.1, Number of unique lncRNAs: 1
# Contig: NW_020869164.1, Number of unique lncRNAs: 2
# Contig: NW_020869166.1, Number of unique lncRNAs: 1
# Contig: NW_020869172.1, Number of unique lncRNAs: 2
# Contig: NW_020869177.1, Number of unique lncRNAs: 1
# Contig: NW_020869178.1, Number of unique lncRNAs: 2
# Contig: NW_020869181.1, Number of unique lncRNAs: 2
# Contig: NW_020869183.1, Number of unique lncRNAs: 2
# Contig: NW_020869189.1, Number of unique lncRNAs: 3
# Contig: NW_020869190.1, Number of unique lncRNAs: 1
# Contig: NW_020869195.1, Number of unique lncRNAs: 1
# Contig: NW_020869196.1, Number of unique lncRNAs: 1
# Contig: NW_020869206.1, Number of unique lncRNAs: 2
# Contig: NW_020869207.1, Number of unique lncRNAs: 15
# Contig: NW_020869210.1, Number of unique lncRNAs: 1
# Contig: NW_020869211.1, Number of unique lncRNAs: 1
# Contig: NW_020869212.1, Number of unique lncRNAs: 1
# Contig: NW_020869213.1, Number of unique lncRNAs: 1
# Contig: NW_020869216.1, Number of unique lncRNAs: 1
# Contig: NW_020869218.1, Number of unique lncRNAs: 7
# Contig: NW_020869222.1, Number of unique lncRNAs: 27
# Contig: NW_020869223.1, Number of unique lncRNAs: 1
# Contig: NW_020869224.1, Number of unique lncRNAs: 3
# Contig: NW_020869227.1, Number of unique lncRNAs: 2
# Contig: NW_020869230.1, Number of unique lncRNAs: 2
# Contig: NW_020869235.1, Number of unique lncRNAs: 1
# Contig: NW_020869236.1, Number of unique lncRNAs: 1
# Contig: NW_020869239.1, Number of unique lncRNAs: 1
# Contig: NW_020869250.1, Number of unique lncRNAs: 1
# Contig: NW_020869259.1, Number of unique lncRNAs: 5
# Contig: NW_020869260.1, Number of unique lncRNAs: 1
# Contig: NW_020869262.1, Number of unique lncRNAs: 3
# Contig: NW_020869278.1, Number of unique lncRNAs: 1
# Contig: NW_020869295.1, Number of unique lncRNAs: 1
# Contig: NW_020869299.1, Number of unique lncRNAs: 1
# Contig: NW_020869300.1, Number of unique lncRNAs: 1
# Contig: NW_020869301.1, Number of unique lncRNAs: 2
# Contig: NW_020869305.1, Number of unique lncRNAs: 2
# Contig: NW_020869308.1, Number of unique lncRNAs: 1
# Contig: NW_020869315.1, Number of unique lncRNAs: 1
# Contig: NW_020869319.1, Number of unique lncRNAs: 1
# Contig: NW_020869321.1, Number of unique lncRNAs: 2
# Contig: NW_020869330.1, Number of unique lncRNAs: 2
# Contig: NW_020869331.1, Number of unique lncRNAs: 5
# Contig: NW_020869335.1, Number of unique lncRNAs: 2
# Contig: NW_020869353.1, Number of unique lncRNAs: 1
# Contig: NW_020869368.1, Number of unique lncRNAs: 1
# Contig: NW_020869371.1, Number of unique lncRNAs: 3
# Contig: NW_020869374.1, Number of unique lncRNAs: 1
# Contig: NW_020869379.1, Number of unique lncRNAs: 1
# Contig: NW_020869380.1, Number of unique lncRNAs: 1
# Contig: NW_020869385.1, Number of unique lncRNAs: 2
# Contig: NW_020869386.1, Number of unique lncRNAs: 2
# Contig: NW_020869390.1, Number of unique lncRNAs: 1
# Contig: NW_020869391.1, Number of unique lncRNAs: 7
# Contig: NW_020869393.1, Number of unique lncRNAs: 1
# Contig: NW_020869399.1, Number of unique lncRNAs: 1
# Contig: NW_020869408.1, Number of unique lncRNAs: 1
# Contig: NW_020869409.1, Number of unique lncRNAs: 1
# Contig: NW_020869414.1, Number of unique lncRNAs: 1
# Contig: NW_020869415.1, Number of unique lncRNAs: 1
# Contig: NW_020869416.1, Number of unique lncRNAs: 1
# Contig: NW_020869419.1, Number of unique lncRNAs: 1
# Contig: NW_020869420.1, Number of unique lncRNAs: 2
# Contig: NW_020869426.1, Number of unique lncRNAs: 1
# Contig: NW_020869429.1, Number of unique lncRNAs: 3
# Contig: NW_020869433.1, Number of unique lncRNAs: 1
# Contig: NW_020869435.1, Number of unique lncRNAs: 1
# Contig: NW_020869438.1, Number of unique lncRNAs: 2
# Contig: NW_020869444.1, Number of unique lncRNAs: 1
# Contig: NW_020869451.1, Number of unique lncRNAs: 2
# Contig: NW_020869460.1, Number of unique lncRNAs: 1
# Contig: NW_020869463.1, Number of unique lncRNAs: 1
# Contig: NW_020869465.1, Number of unique lncRNAs: 2
# Contig: NW_020869469.1, Number of unique lncRNAs: 2
# Contig: NW_020869470.1, Number of unique lncRNAs: 1
# Contig: NW_020869471.1, Number of unique lncRNAs: 1
# Contig: NW_020869474.1, Number of unique lncRNAs: 1
# Contig: NW_020869476.1, Number of unique lncRNAs: 1
# Contig: NW_020869478.1, Number of unique lncRNAs: 1
# Contig: NW_020869481.1, Number of unique lncRNAs: 1
# Contig: NW_020869482.1, Number of unique lncRNAs: 1
# Contig: NW_020869484.1, Number of unique lncRNAs: 1
# Contig: NW_020869488.1, Number of unique lncRNAs: 2
# Contig: NW_020869492.1, Number of unique lncRNAs: 4
# Contig: NW_020869493.1, Number of unique lncRNAs: 1
# Contig: NW_020869494.1, Number of unique lncRNAs: 1
# Contig: NW_020869495.1, Number of unique lncRNAs: 1
# Contig: NW_020869497.1, Number of unique lncRNAs: 2
# Contig: NW_020869500.1, Number of unique lncRNAs: 1
# Contig: NW_020869502.1, Number of unique lncRNAs: 3
# Contig: NW_020869504.1, Number of unique lncRNAs: 2
# Contig: NW_020869515.1, Number of unique lncRNAs: 1
# Contig: NW_020869520.1, Number of unique lncRNAs: 1
# Contig: NW_020869526.1, Number of unique lncRNAs: 2
# Contig: NW_020869529.1, Number of unique lncRNAs: 1
# Contig: NW_020869531.1, Number of unique lncRNAs: 1
# Contig: NW_020869532.1, Number of unique lncRNAs: 1
# Contig: NW_020869539.1, Number of unique lncRNAs: 2
# Contig: NW_020869540.1, Number of unique lncRNAs: 4
# Contig: NW_020869544.1, Number of unique lncRNAs: 3
# Contig: NW_020869547.1, Number of unique lncRNAs: 1
# Contig: NW_020869550.1, Number of unique lncRNAs: 2
# Contig: NW_020869553.1, Number of unique lncRNAs: 2
# Contig: NW_020869558.1, Number of unique lncRNAs: 1
# Contig: NW_020869560.1, Number of unique lncRNAs: 1
# Contig: NW_020869562.1, Number of unique lncRNAs: 1
# Contig: NW_020869564.1, Number of unique lncRNAs: 2
# Contig: NW_020869565.1, Number of unique lncRNAs: 1
# Contig: NW_020869572.1, Number of unique lncRNAs: 1
# Contig: NW_020869578.1, Number of unique lncRNAs: 1
# Contig: NW_020869579.1, Number of unique lncRNAs: 1
# Contig: NW_020869580.1, Number of unique lncRNAs: 1
# Contig: NW_020869588.1, Number of unique lncRNAs: 1
# Contig: NW_020869590.1, Number of unique lncRNAs: 1
# Contig: NW_020869591.1, Number of unique lncRNAs: 1
# Contig: NW_020869594.1, Number of unique lncRNAs: 1
# Contig: NW_020869597.1, Number of unique lncRNAs: 3
# Contig: NW_020869598.1, Number of unique lncRNAs: 1
# Contig: NW_020869599.1, Number of unique lncRNAs: 2
# Contig: NW_020869600.1, Number of unique lncRNAs: 2
# Contig: NW_020869601.1, Number of unique lncRNAs: 2
# Contig: NW_020869604.1, Number of unique lncRNAs: 4
# Contig: NW_020869607.1, Number of unique lncRNAs: 1
# Contig: NW_020869610.1, Number of unique lncRNAs: 1
# Contig: NW_020869611.1, Number of unique lncRNAs: 3
# Contig: NW_020869612.1, Number of unique lncRNAs: 1
# Contig: NW_020869613.1, Number of unique lncRNAs: 1
# Contig: NW_020869615.1, Number of unique lncRNAs: 2
# Contig: NW_020869620.1, Number of unique lncRNAs: 1
# Contig: NW_020869623.1, Number of unique lncRNAs: 2
# Contig: NW_020869629.1, Number of unique lncRNAs: 2
# Contig: NW_020869630.1, Number of unique lncRNAs: 2
# Contig: NW_020869631.1, Number of unique lncRNAs: 2
# Contig: NW_020869632.1, Number of unique lncRNAs: 1
# Contig: NW_020869633.1, Number of unique lncRNAs: 1
# Contig: NW_020869635.1, Number of unique lncRNAs: 1
# Contig: NW_020869637.1, Number of unique lncRNAs: 1
# Contig: NW_020869638.1, Number of unique lncRNAs: 2
# Contig: NW_020869641.1, Number of unique lncRNAs: 1
# Contig: NW_020869644.1, Number of unique lncRNAs: 2
# Contig: NW_020869647.1, Number of unique lncRNAs: 1
# Contig: NW_020869652.1, Number of unique lncRNAs: 1
# Contig: NW_020869654.1, Number of unique lncRNAs: 1
# Contig: NW_020869659.1, Number of unique lncRNAs: 1
# Contig: NW_020869660.1, Number of unique lncRNAs: 2
# Contig: NW_020869663.1, Number of unique lncRNAs: 1
# Contig: NW_020869666.1, Number of unique lncRNAs: 1
# Contig: NW_020869678.1, Number of unique lncRNAs: 5
# Contig: NW_020869682.1, Number of unique lncRNAs: 2
# Contig: NW_020869695.1, Number of unique lncRNAs: 4
# Contig: NW_020869696.1, Number of unique lncRNAs: 1
# Contig: NW_020869702.1, Number of unique lncRNAs: 1
# Contig: NW_020869704.1, Number of unique lncRNAs: 2
# Contig: NW_020869705.1, Number of unique lncRNAs: 1
# Contig: NW_020869708.1, Number of unique lncRNAs: 2
# Contig: NW_020869712.1, Number of unique lncRNAs: 1
# Contig: NW_020869713.1, Number of unique lncRNAs: 4
# Contig: NW_020869714.1, Number of unique lncRNAs: 3
# Contig: NW_020869719.1, Number of unique lncRNAs: 3
# Contig: NW_020869721.1, Number of unique lncRNAs: 1
# Contig: NW_020869723.1, Number of unique lncRNAs: 4
# Contig: NW_020869727.1, Number of unique lncRNAs: 1
# Contig: NW_020869728.1, Number of unique lncRNAs: 2
# Contig: NW_020869735.1, Number of unique lncRNAs: 1
# Contig: NW_020869736.1, Number of unique lncRNAs: 1
# Contig: NW_020869740.1, Number of unique lncRNAs: 7
# Contig: NW_020869742.1, Number of unique lncRNAs: 1
# Contig: NW_020869750.1, Number of unique lncRNAs: 1
# Contig: NW_020869751.1, Number of unique lncRNAs: 1
# Contig: NW_020869760.1, Number of unique lncRNAs: 1
# Contig: NW_020869770.1, Number of unique lncRNAs: 4
# Contig: NW_020869774.1, Number of unique lncRNAs: 2
# Contig: NW_020869775.1, Number of unique lncRNAs: 1
# Contig: NW_020869778.1, Number of unique lncRNAs: 1
# Contig: NW_020869781.1, Number of unique lncRNAs: 2
# Contig: NW_020869784.1, Number of unique lncRNAs: 1
# Contig: NW_020869788.1, Number of unique lncRNAs: 2
# Contig: NW_020869790.1, Number of unique lncRNAs: 1
# Contig: NW_020869791.1, Number of unique lncRNAs: 2
# Contig: NW_020869794.1, Number of unique lncRNAs: 1
# Contig: NW_020869800.1, Number of unique lncRNAs: 3
# Contig: NW_020869804.1, Number of unique lncRNAs: 2
# Contig: NW_020869806.1, Number of unique lncRNAs: 1
# Contig: NW_020869807.1, Number of unique lncRNAs: 2
# Contig: NW_020869822.1, Number of unique lncRNAs: 1
# Contig: NW_020869823.1, Number of unique lncRNAs: 3
# Contig: NW_020869825.1, Number of unique lncRNAs: 2
# Contig: NW_020869826.1, Number of unique lncRNAs: 3
# Contig: NW_020869829.1, Number of unique lncRNAs: 1
# Contig: NW_020869834.1, Number of unique lncRNAs: 1
# Contig: NW_020869837.1, Number of unique lncRNAs: 2
# Contig: NW_020869841.1, Number of unique lncRNAs: 1
# Contig: NW_020869844.1, Number of unique lncRNAs: 3
# Contig: NW_020869846.1, Number of unique lncRNAs: 1
# Contig: NW_020869851.1, Number of unique lncRNAs: 1
# Contig: NW_020869857.1, Number of unique lncRNAs: 1
# Contig: NW_020869858.1, Number of unique lncRNAs: 3
# Contig: NW_020869859.1, Number of unique lncRNAs: 1
# Contig: NW_020869864.1, Number of unique lncRNAs: 1
# Contig: NW_020869865.1, Number of unique lncRNAs: 1
# Contig: NW_020869868.1, Number of unique lncRNAs: 1
# Contig: NW_020869870.1, Number of unique lncRNAs: 2
# Contig: NW_020869883.1, Number of unique lncRNAs: 1
# Contig: NW_020869888.1, Number of unique lncRNAs: 2
# Contig: NW_020869889.1, Number of unique lncRNAs: 1
# Contig: NW_020869892.1, Number of unique lncRNAs: 2
# Contig: NW_020869894.1, Number of unique lncRNAs: 1
# Contig: NW_020869897.1, Number of unique lncRNAs: 2
# Contig: NW_020869903.1, Number of unique lncRNAs: 1
# Contig: NW_020869904.1, Number of unique lncRNAs: 3
# Contig: NW_020869906.1, Number of unique lncRNAs: 1
# Contig: NW_020869908.1, Number of unique lncRNAs: 1
# Contig: NW_020869912.1, Number of unique lncRNAs: 2
# Contig: NW_020869913.1, Number of unique lncRNAs: 3
# Contig: NW_020869915.1, Number of unique lncRNAs: 4
# Contig: NW_020869916.1, Number of unique lncRNAs: 1
# Contig: NW_020869917.1, Number of unique lncRNAs: 2
# Contig: NW_020869919.1, Number of unique lncRNAs: 1
# Contig: NW_020869927.1, Number of unique lncRNAs: 1
# Contig: NW_020869934.1, Number of unique lncRNAs: 1
# Contig: NW_020869936.1, Number of unique lncRNAs: 9
# Contig: NW_020869938.1, Number of unique lncRNAs: 1
# Contig: NW_020869951.1, Number of unique lncRNAs: 1
# Contig: NW_020869953.1, Number of unique lncRNAs: 1
# Contig: NW_020869959.1, Number of unique lncRNAs: 3
# Contig: NW_020869964.1, Number of unique lncRNAs: 1
# Contig: NW_020869967.1, Number of unique lncRNAs: 1
# Contig: NW_020869969.1, Number of unique lncRNAs: 1
# Contig: NW_020869971.1, Number of unique lncRNAs: 1
# Contig: NW_020869978.1, Number of unique lncRNAs: 4
# Contig: NW_020869981.1, Number of unique lncRNAs: 3
# Contig: NW_020869983.1, Number of unique lncRNAs: 5
# Contig: NW_020869984.1, Number of unique lncRNAs: 1
# Contig: NW_020869987.1, Number of unique lncRNAs: 1
# Contig: NW_020869988.1, Number of unique lncRNAs: 9
# Contig: NW_020869989.1, Number of unique lncRNAs: 1
# Contig: NW_020869994.1, Number of unique lncRNAs: 15
# Contig: NW_020870000.1, Number of unique lncRNAs: 2
# Contig: NW_020870009.1, Number of unique lncRNAs: 4
# Contig: NW_020870010.1, Number of unique lncRNAs: 3
# Contig: NW_020870016.1, Number of unique lncRNAs: 2
# Contig: NW_020870017.1, Number of unique lncRNAs: 1
# Contig: NW_020870019.1, Number of unique lncRNAs: 2
# Contig: NW_020870023.1, Number of unique lncRNAs: 1
# Contig: NW_020870026.1, Number of unique lncRNAs: 5
# Contig: NW_020870027.1, Number of unique lncRNAs: 2
# Contig: NW_020870032.1, Number of unique lncRNAs: 1
# Contig: NW_020870036.1, Number of unique lncRNAs: 1
# Contig: NW_020870040.1, Number of unique lncRNAs: 1
# Contig: NW_020870042.1, Number of unique lncRNAs: 1
# Contig: NW_020870048.1, Number of unique lncRNAs: 2
# Contig: NW_020870053.1, Number of unique lncRNAs: 1
# Contig: NW_020870055.1, Number of unique lncRNAs: 1
# Contig: NW_020870056.1, Number of unique lncRNAs: 1
# Contig: NW_020870065.1, Number of unique lncRNAs: 1
# Contig: NW_020870069.1, Number of unique lncRNAs: 3
# Contig: NW_020870070.1, Number of unique lncRNAs: 1
# Contig: NW_020870071.1, Number of unique lncRNAs: 1
# Contig: NW_020870075.1, Number of unique lncRNAs: 2
# Contig: NW_020870080.1, Number of unique lncRNAs: 3
# Contig: NW_020870085.1, Number of unique lncRNAs: 1
# Contig: NW_020870091.1, Number of unique lncRNAs: 8
# Contig: NW_020870092.1, Number of unique lncRNAs: 2
# Contig: NW_020870095.1, Number of unique lncRNAs: 1
# Contig: NW_020870096.1, Number of unique lncRNAs: 3
# Contig: NW_020870097.1, Number of unique lncRNAs: 1
# Contig: NW_020870100.1, Number of unique lncRNAs: 1
# Contig: NW_020870101.1, Number of unique lncRNAs: 2
# Contig: NW_020870103.1, Number of unique lncRNAs: 1
# Contig: NW_020870105.1, Number of unique lncRNAs: 1
# Contig: NW_020870106.1, Number of unique lncRNAs: 4
# Contig: NW_020870108.1, Number of unique lncRNAs: 1
# Contig: NW_020870110.1, Number of unique lncRNAs: 1
# Contig: NW_020870111.1, Number of unique lncRNAs: 2
# Contig: NW_020870116.1, Number of unique lncRNAs: 2
# Contig: NW_020870117.1, Number of unique lncRNAs: 1
# Contig: NW_020870119.1, Number of unique lncRNAs: 1
# Contig: NW_020870120.1, Number of unique lncRNAs: 4
# Contig: NW_020870125.1, Number of unique lncRNAs: 1
# Contig: NW_020870127.1, Number of unique lncRNAs: 2
# Contig: NW_020870128.1, Number of unique lncRNAs: 1
# Contig: NW_020870129.1, Number of unique lncRNAs: 1
# Contig: NW_020870130.1, Number of unique lncRNAs: 2
# Contig: NW_020870133.1, Number of unique lncRNAs: 2
# Contig: NW_020870137.1, Number of unique lncRNAs: 1
# Contig: NW_020870144.1, Number of unique lncRNAs: 1
# Contig: NW_020870146.1, Number of unique lncRNAs: 1
# Contig: NW_020870155.1, Number of unique lncRNAs: 2
# Contig: NW_020870157.1, Number of unique lncRNAs: 1
# Contig: NW_020870158.1, Number of unique lncRNAs: 1
# Contig: NW_020870167.1, Number of unique lncRNAs: 1
# Contig: NW_020870171.1, Number of unique lncRNAs: 3
# Contig: NW_020870172.1, Number of unique lncRNAs: 4
# Contig: NW_020870174.1, Number of unique lncRNAs: 1
# Contig: NW_020870179.1, Number of unique lncRNAs: 2
# Contig: NW_020870182.1, Number of unique lncRNAs: 4
# Contig: NW_020870187.1, Number of unique lncRNAs: 1
# Contig: NW_020870189.1, Number of unique lncRNAs: 1
# Contig: NW_020870193.1, Number of unique lncRNAs: 1
# Contig: NW_020870195.1, Number of unique lncRNAs: 1
# Contig: NW_020870197.1, Number of unique lncRNAs: 2
# Contig: NW_020870203.1, Number of unique lncRNAs: 1
# Contig: NW_020870204.1, Number of unique lncRNAs: 9
# Contig: NW_020870206.1, Number of unique lncRNAs: 1
# Contig: NW_020870208.1, Number of unique lncRNAs: 1
# Contig: NW_020870217.1, Number of unique lncRNAs: 2
# Contig: NW_020870219.1, Number of unique lncRNAs: 1
# Contig: NW_020870232.1, Number of unique lncRNAs: 3
# Contig: NW_020870236.1, Number of unique lncRNAs: 2
# Contig: NW_020870243.1, Number of unique lncRNAs: 2
# Contig: NW_020870248.1, Number of unique lncRNAs: 2
# Contig: NW_020870249.1, Number of unique lncRNAs: 1
# Contig: NW_020870251.1, Number of unique lncRNAs: 1
# Contig: NW_020870256.1, Number of unique lncRNAs: 1
# Contig: NW_020870261.1, Number of unique lncRNAs: 1
# Contig: NW_020870270.1, Number of unique lncRNAs: 1
# Contig: NW_020870273.1, Number of unique lncRNAs: 1
# Contig: NW_020870274.1, Number of unique lncRNAs: 2
# Contig: NW_020870276.1, Number of unique lncRNAs: 1
# Contig: NW_020870287.1, Number of unique lncRNAs: 2
# Contig: NW_020870289.1, Number of unique lncRNAs: 3
# Contig: NW_020870292.1, Number of unique lncRNAs: 1
# Contig: NW_020870294.1, Number of unique lncRNAs: 1
# Contig: NW_020870297.1, Number of unique lncRNAs: 1
# Contig: NW_020870299.1, Number of unique lncRNAs: 4
# Contig: NW_020870300.1, Number of unique lncRNAs: 2
# Contig: NW_020870301.1, Number of unique lncRNAs: 2
# Contig: NW_020870305.1, Number of unique lncRNAs: 1
# Contig: NW_020870307.1, Number of unique lncRNAs: 4
# Contig: NW_020870308.1, Number of unique lncRNAs: 1
# Contig: NW_020870310.1, Number of unique lncRNAs: 2
# Contig: NW_020870315.1, Number of unique lncRNAs: 1
# Contig: NW_020870318.1, Number of unique lncRNAs: 1
# Contig: NW_020870320.1, Number of unique lncRNAs: 1
# Contig: NW_020870322.1, Number of unique lncRNAs: 1
# Contig: NW_020870324.1, Number of unique lncRNAs: 1
# Contig: NW_020870328.1, Number of unique lncRNAs: 10
# Contig: NW_020870333.1, Number of unique lncRNAs: 1
# Contig: NW_020870336.1, Number of unique lncRNAs: 1
# Contig: NW_020870340.1, Number of unique lncRNAs: 1
# Contig: NW_020870348.1, Number of unique lncRNAs: 2
# Contig: NW_020870358.1, Number of unique lncRNAs: 2
# Contig: NW_020870361.1, Number of unique lncRNAs: 1
# Contig: NW_020870363.1, Number of unique lncRNAs: 1
# Contig: NW_020870370.1, Number of unique lncRNAs: 1
# Contig: NW_020870377.1, Number of unique lncRNAs: 1
# Contig: NW_020870379.1, Number of unique lncRNAs: 2
# Contig: NW_020870381.1, Number of unique lncRNAs: 1
# Contig: NW_020870383.1, Number of unique lncRNAs: 3
# Contig: NW_020870391.1, Number of unique lncRNAs: 1
# Contig: NW_020870395.1, Number of unique lncRNAs: 1
# Contig: NW_020870396.1, Number of unique lncRNAs: 3
# Contig: NW_020870397.1, Number of unique lncRNAs: 5
# Contig: NW_020870403.1, Number of unique lncRNAs: 2
# Contig: NW_020870406.1, Number of unique lncRNAs: 1
# Contig: NW_020870408.1, Number of unique lncRNAs: 1
# Contig: NW_020870418.1, Number of unique lncRNAs: 4
# Contig: NW_020870419.1, Number of unique lncRNAs: 1
# Contig: NW_020870425.1, Number of unique lncRNAs: 3
# Contig: NW_020870429.1, Number of unique lncRNAs: 1
# Contig: NW_020870435.1, Number of unique lncRNAs: 1
# Contig: NW_020870437.1, Number of unique lncRNAs: 2
# Contig: NW_020870439.1, Number of unique lncRNAs: 1
# Contig: NW_020870440.1, Number of unique lncRNAs: 1
# Contig: NW_020870444.1, Number of unique lncRNAs: 1
# Contig: NW_020870451.1, Number of unique lncRNAs: 1
# Contig: NW_020870458.1, Number of unique lncRNAs: 1
# Contig: NW_020870460.1, Number of unique lncRNAs: 1
# Contig: NW_020870463.1, Number of unique lncRNAs: 5
# Contig: NW_020870464.1, Number of unique lncRNAs: 1
# Contig: NW_020870466.1, Number of unique lncRNAs: 1
# Contig: NW_020870467.1, Number of unique lncRNAs: 1
# Contig: NW_020870469.1, Number of unique lncRNAs: 1
# Contig: NW_020870475.1, Number of unique lncRNAs: 1
# Contig: NW_020870477.1, Number of unique lncRNAs: 4
# Contig: NW_020870478.1, Number of unique lncRNAs: 1
# Contig: NW_020870487.1, Number of unique lncRNAs: 1
# Contig: NW_020870491.1, Number of unique lncRNAs: 3
# Contig: NW_020870494.1, Number of unique lncRNAs: 1
# Contig: NW_020870500.1, Number of unique lncRNAs: 2
# Contig: NW_020870503.1, Number of unique lncRNAs: 1
# Contig: NW_020870505.1, Number of unique lncRNAs: 1
# Contig: NW_020870506.1, Number of unique lncRNAs: 2
# Contig: NW_020870511.1, Number of unique lncRNAs: 3
# Contig: NW_020870513.1, Number of unique lncRNAs: 6
# Contig: NW_020870520.1, Number of unique lncRNAs: 1
# Contig: NW_020870526.1, Number of unique lncRNAs: 1
# Contig: NW_020870531.1, Number of unique lncRNAs: 1
# Contig: NW_020870533.1, Number of unique lncRNAs: 1
# Contig: NW_020870539.1, Number of unique lncRNAs: 1
# Contig: NW_020870541.1, Number of unique lncRNAs: 1
# Contig: NW_020870542.1, Number of unique lncRNAs: 1
# Contig: NW_020870544.1, Number of unique lncRNAs: 1
# Contig: NW_020870549.1, Number of unique lncRNAs: 1
# Contig: NW_020870553.1, Number of unique lncRNAs: 2
# Contig: NW_020870556.1, Number of unique lncRNAs: 2
# Contig: NW_020870559.1, Number of unique lncRNAs: 1
# Contig: NW_020870561.1, Number of unique lncRNAs: 1
# Contig: NW_020870567.1, Number of unique lncRNAs: 2
# Contig: NW_020870571.1, Number of unique lncRNAs: 1
# Contig: NW_020870572.1, Number of unique lncRNAs: 4
# Contig: NW_020870573.1, Number of unique lncRNAs: 3
# Contig: NW_020870578.1, Number of unique lncRNAs: 1
# Contig: NW_020870582.1, Number of unique lncRNAs: 5
# Contig: NW_020870588.1, Number of unique lncRNAs: 2
# Contig: NW_020870591.1, Number of unique lncRNAs: 21
# Contig: NW_020870592.1, Number of unique lncRNAs: 2
# Contig: NW_020870596.1, Number of unique lncRNAs: 1
# Contig: NW_020870599.1, Number of unique lncRNAs: 1
# Contig: NW_020870602.1, Number of unique lncRNAs: 1
# Contig: NW_020870603.1, Number of unique lncRNAs: 2
# Contig: NW_020870604.1, Number of unique lncRNAs: 3
# Contig: NW_020870605.1, Number of unique lncRNAs: 2
# Contig: NW_020870606.1, Number of unique lncRNAs: 1
# Contig: NW_020870614.1, Number of unique lncRNAs: 1
# Contig: NW_020870616.1, Number of unique lncRNAs: 1
# Contig: NW_020870618.1, Number of unique lncRNAs: 1
# Contig: NW_020870625.1, Number of unique lncRNAs: 2
# Contig: NW_020870629.1, Number of unique lncRNAs: 6
# Contig: NW_020870632.1, Number of unique lncRNAs: 1
# Contig: NW_020870634.1, Number of unique lncRNAs: 1
# Contig: NW_020870635.1, Number of unique lncRNAs: 1
# Contig: NW_020870636.1, Number of unique lncRNAs: 2
# Contig: NW_020870645.1, Number of unique lncRNAs: 1
# Contig: NW_020870649.1, Number of unique lncRNAs: 1
# Contig: NW_020870651.1, Number of unique lncRNAs: 2
# Contig: NW_020870664.1, Number of unique lncRNAs: 1
# Contig: NW_020870669.1, Number of unique lncRNAs: 1
# Contig: NW_020870671.1, Number of unique lncRNAs: 2
# Contig: NW_020870679.1, Number of unique lncRNAs: 1
# Contig: NW_020870680.1, Number of unique lncRNAs: 1
# Contig: NW_020870685.1, Number of unique lncRNAs: 1
# Contig: NW_020870688.1, Number of unique lncRNAs: 1
# Contig: NW_020870689.1, Number of unique lncRNAs: 4
# Contig: NW_020870690.1, Number of unique lncRNAs: 1
# Contig: NW_020870692.1, Number of unique lncRNAs: 2
# Contig: NW_020870695.1, Number of unique lncRNAs: 1
# Contig: NW_020870697.1, Number of unique lncRNAs: 1
# Contig: NW_020870699.1, Number of unique lncRNAs: 1
# Contig: NW_020870700.1, Number of unique lncRNAs: 2
# Contig: NW_020870710.1, Number of unique lncRNAs: 2
# Contig: NW_020870716.1, Number of unique lncRNAs: 1
# Contig: NW_020870719.1, Number of unique lncRNAs: 1
# Contig: NW_020870721.1, Number of unique lncRNAs: 2
# Contig: NW_020870726.1, Number of unique lncRNAs: 1
# Contig: NW_020870730.1, Number of unique lncRNAs: 1
# Contig: NW_020870734.1, Number of unique lncRNAs: 2
# Contig: NW_020870747.1, Number of unique lncRNAs: 2
# Contig: NW_020870748.1, Number of unique lncRNAs: 2
# Contig: NW_020870760.1, Number of unique lncRNAs: 3
# Contig: NW_020870761.1, Number of unique lncRNAs: 2
# Contig: NW_020870762.1, Number of unique lncRNAs: 1
# Contig: NW_020870767.1, Number of unique lncRNAs: 2
# Contig: NW_020870769.1, Number of unique lncRNAs: 1
# Contig: NW_020870770.1, Number of unique lncRNAs: 1
# Contig: NW_020870771.1, Number of unique lncRNAs: 2
# Contig: NW_020870780.1, Number of unique lncRNAs: 1
# Contig: NW_020870781.1, Number of unique lncRNAs: 4
# Contig: NW_020870784.1, Number of unique lncRNAs: 1
# Contig: NW_020870786.1, Number of unique lncRNAs: 1
# Contig: NW_020870788.1, Number of unique lncRNAs: 2
# Contig: NW_020870789.1, Number of unique lncRNAs: 1
# Contig: NW_020870791.1, Number of unique lncRNAs: 1
# Contig: NW_020870794.1, Number of unique lncRNAs: 2
# Contig: NW_020870795.1, Number of unique lncRNAs: 2
# Contig: NW_020870796.1, Number of unique lncRNAs: 2
# Contig: NW_020870801.1, Number of unique lncRNAs: 5
# Contig: NW_020870811.1, Number of unique lncRNAs: 3
# Contig: NW_020870815.1, Number of unique lncRNAs: 1
# Contig: NW_020870818.1, Number of unique lncRNAs: 1
# Contig: NW_020870819.1, Number of unique lncRNAs: 1
# Contig: NW_020870823.1, Number of unique lncRNAs: 1
# Contig: NW_020870839.1, Number of unique lncRNAs: 3
# Contig: NW_020870846.1, Number of unique lncRNAs: 1
# Contig: NW_020870848.1, Number of unique lncRNAs: 1
# Contig: NW_020870858.1, Number of unique lncRNAs: 4
# Contig: NW_020870859.1, Number of unique lncRNAs: 1
# Contig: NW_020870865.1, Number of unique lncRNAs: 1
# Contig: NW_020870873.1, Number of unique lncRNAs: 2
# Contig: NW_020870874.1, Number of unique lncRNAs: 6
# Contig: NW_020870881.1, Number of unique lncRNAs: 4
# Contig: NW_020870885.1, Number of unique lncRNAs: 15
# Contig: NW_020870886.1, Number of unique lncRNAs: 9
# Contig: NW_020870888.1, Number of unique lncRNAs: 2
# Contig: NW_020870899.1, Number of unique lncRNAs: 1
# Contig: NW_020870902.1, Number of unique lncRNAs: 1
# Contig: NW_020870906.1, Number of unique lncRNAs: 1
# Contig: NW_020870907.1, Number of unique lncRNAs: 1
# Contig: NW_020870908.1, Number of unique lncRNAs: 2
# Contig: NW_020870911.1, Number of unique lncRNAs: 1
# Contig: NW_020870916.1, Number of unique lncRNAs: 11
# Contig: NW_020870918.1, Number of unique lncRNAs: 2
# Contig: NW_020870924.1, Number of unique lncRNAs: 1
# Contig: NW_020870929.1, Number of unique lncRNAs: 2
# Contig: NW_020870934.1, Number of unique lncRNAs: 1
# Contig: NW_020870938.1, Number of unique lncRNAs: 1
# Contig: NW_020870940.1, Number of unique lncRNAs: 1
# Contig: NW_020870941.1, Number of unique lncRNAs: 1
# Contig: NW_020870944.1, Number of unique lncRNAs: 3
# Contig: NW_020870951.1, Number of unique lncRNAs: 1
# Contig: NW_020870955.1, Number of unique lncRNAs: 1
# Contig: NW_020870956.1, Number of unique lncRNAs: 3
# Contig: NW_020870962.1, Number of unique lncRNAs: 1
# Contig: NW_020870967.1, Number of unique lncRNAs: 1
# Contig: NW_020870969.1, Number of unique lncRNAs: 1
# Contig: NW_020870971.1, Number of unique lncRNAs: 2
# Contig: NW_020870973.1, Number of unique lncRNAs: 1
# Contig: NW_020870979.1, Number of unique lncRNAs: 1
# Contig: NW_020870986.1, Number of unique lncRNAs: 1
# Contig: NW_020870988.1, Number of unique lncRNAs: 2
# Contig: NW_020870989.1, Number of unique lncRNAs: 1
# Contig: NW_020870990.1, Number of unique lncRNAs: 3
# Contig: NW_020870991.1, Number of unique lncRNAs: 1
# Contig: NW_020870992.1, Number of unique lncRNAs: 1
# Contig: NW_020870999.1, Number of unique lncRNAs: 2
# Contig: NW_020871000.1, Number of unique lncRNAs: 2
# Contig: NW_020871003.1, Number of unique lncRNAs: 2
# Contig: NW_020871004.1, Number of unique lncRNAs: 2
# Contig: NW_020871006.1, Number of unique lncRNAs: 2
# Contig: NW_020871010.1, Number of unique lncRNAs: 2
# Contig: NW_020871011.1, Number of unique lncRNAs: 2
# Contig: NW_020871012.1, Number of unique lncRNAs: 1
# Contig: NW_020871014.1, Number of unique lncRNAs: 2
# Contig: NW_020871018.1, Number of unique lncRNAs: 5
# Contig: NW_020871039.1, Number of unique lncRNAs: 1
# Contig: NW_020871041.1, Number of unique lncRNAs: 1
# Contig: NW_020871044.1, Number of unique lncRNAs: 1
# Contig: NW_020871046.1, Number of unique lncRNAs: 1
# Contig: NW_020871049.1, Number of unique lncRNAs: 3
# Contig: NW_020871054.1, Number of unique lncRNAs: 4
# Contig: NW_020871055.1, Number of unique lncRNAs: 3
# Contig: NW_020871057.1, Number of unique lncRNAs: 2
# Contig: NW_020871058.1, Number of unique lncRNAs: 2
# Contig: NW_020871061.1, Number of unique lncRNAs: 2
# Contig: NW_020871062.1, Number of unique lncRNAs: 1
# Contig: NW_020871067.1, Number of unique lncRNAs: 1
# Contig: NW_020871069.1, Number of unique lncRNAs: 2
# Contig: NW_020871070.1, Number of unique lncRNAs: 1
# Contig: NW_020871071.1, Number of unique lncRNAs: 2
# Contig: NW_020871072.1, Number of unique lncRNAs: 3
# Contig: NW_020871078.1, Number of unique lncRNAs: 3
# Contig: NW_020871081.1, Number of unique lncRNAs: 1
# Contig: NW_020871082.1, Number of unique lncRNAs: 1
# Contig: NW_020871086.1, Number of unique lncRNAs: 3
# Contig: NW_020871088.1, Number of unique lncRNAs: 3
# Contig: NW_020871089.1, Number of unique lncRNAs: 1
# Contig: NW_020871090.1, Number of unique lncRNAs: 4
# Contig: NW_020871094.1, Number of unique lncRNAs: 3
# Contig: NW_020871097.1, Number of unique lncRNAs: 1
# Contig: NW_020871102.1, Number of unique lncRNAs: 3
# Contig: NW_020871103.1, Number of unique lncRNAs: 1
# Contig: NW_020871107.1, Number of unique lncRNAs: 3
# Contig: NW_020871108.1, Number of unique lncRNAs: 1
# Contig: NW_020871110.1, Number of unique lncRNAs: 1
# Contig: NW_020871122.1, Number of unique lncRNAs: 1
# Contig: NW_020871128.1, Number of unique lncRNAs: 2
# Contig: NW_020871134.1, Number of unique lncRNAs: 4
# Contig: NW_020871135.1, Number of unique lncRNAs: 1
# Contig: NW_020871138.1, Number of unique lncRNAs: 1
# Contig: NW_020871142.1, Number of unique lncRNAs: 6
# Contig: NW_020871148.1, Number of unique lncRNAs: 1
# Contig: NW_020871162.1, Number of unique lncRNAs: 1
# Contig: NW_020871167.1, Number of unique lncRNAs: 1
# Contig: NW_020871181.1, Number of unique lncRNAs: 1
# Contig: NW_020871183.1, Number of unique lncRNAs: 1
# Contig: NW_020871193.1, Number of unique lncRNAs: 1
# Contig: NW_020871215.1, Number of unique lncRNAs: 1
# Contig: NW_020871234.1, Number of unique lncRNAs: 1
# Contig: NW_020871249.1, Number of unique lncRNAs: 1
# Contig: NW_020871272.1, Number of unique lncRNAs: 1
# Contig: NW_020871279.1, Number of unique lncRNAs: 1
# Contig: NW_020871289.1, Number of unique lncRNAs: 1
# Contig: NW_020871293.1, Number of unique lncRNAs: 1
# Contig: NW_020871294.1, Number of unique lncRNAs: 1
# Contig: NW_020871302.1, Number of unique lncRNAs: 1
# Contig: NW_020871317.1, Number of unique lncRNAs: 1
# Contig: NW_020871323.1, Number of unique lncRNAs: 2
# Contig: NW_020871335.1, Number of unique lncRNAs: 1
# Contig: NW_020871338.1, Number of unique lncRNAs: 1
# Contig: NW_020871339.1, Number of unique lncRNAs: 1
# Contig: NW_020871360.1, Number of unique lncRNAs: 1
# Contig: NW_020871377.1, Number of unique lncRNAs: 2
# Contig: NW_020871395.1, Number of unique lncRNAs: 1
# Contig: NW_020871404.1, Number of unique lncRNAs: 3
# Contig: NW_020871413.1, Number of unique lncRNAs: 1
# Contig: NW_020871422.1, Number of unique lncRNAs: 1
# Contig: NW_020871432.1, Number of unique lncRNAs: 1
# Contig: NW_020871445.1, Number of unique lncRNAs: 1
# Contig: NW_020871469.1, Number of unique lncRNAs: 1
# Contig: NW_020871489.1, Number of unique lncRNAs: 1
# Contig: NW_020871496.1, Number of unique lncRNAs: 1
# Contig: NW_020871505.1, Number of unique lncRNAs: 1
# Contig: NW_020871506.1, Number of unique lncRNAs: 1
# Contig: NW_020871512.1, Number of unique lncRNAs: 1
# Contig: NW_020871520.1, Number of unique lncRNAs: 1
# Contig: NW_020871521.1, Number of unique lncRNAs: 1
# Contig: NW_020871526.1, Number of unique lncRNAs: 1
# Contig: NW_020871534.1, Number of unique lncRNAs: 1
# Contig: NW_020871544.1, Number of unique lncRNAs: 1
# Contig: NW_020871546.1, Number of unique lncRNAs: 1
# Contig: NW_020871564.1, Number of unique lncRNAs: 1
# Contig: NW_020871567.1, Number of unique lncRNAs: 1
# Contig: NW_020871575.1, Number of unique lncRNAs: 2
# Contig: NW_020871588.1, Number of unique lncRNAs: 3
# Contig: NW_020871600.1, Number of unique lncRNAs: 1
# Contig: NW_020871607.1, Number of unique lncRNAs: 8
# Contig: NW_020871609.1, Number of unique lncRNAs: 1
# Contig: NW_020871610.1, Number of unique lncRNAs: 1
# Contig: NW_020871612.1, Number of unique lncRNAs: 2
# Contig: NW_020871622.1, Number of unique lncRNAs: 1
# Contig: NW_020871629.1, Number of unique lncRNAs: 1
# Contig: NW_020871636.1, Number of unique lncRNAs: 1
# Contig: NW_020871641.1, Number of unique lncRNAs: 2
# Contig: NW_020871652.1, Number of unique lncRNAs: 1
# Contig: NW_020871660.1, Number of unique lncRNAs: 1
# Contig: NW_020871663.1, Number of unique lncRNAs: 4
# Contig: NW_020871692.1, Number of unique lncRNAs: 2
# Contig: NW_020871712.1, Number of unique lncRNAs: 1
# Contig: NW_020871718.1, Number of unique lncRNAs: 3
# Contig: NW_020871725.1, Number of unique lncRNAs: 1
# Contig: NW_020871744.1, Number of unique lncRNAs: 2
# Contig: NW_020871756.1, Number of unique lncRNAs: 1
# Contig: NW_020871759.1, Number of unique lncRNAs: 1
# Contig: NW_020871769.1, Number of unique lncRNAs: 1
# Contig: NW_020871771.1, Number of unique lncRNAs: 5
# Contig: NW_020871780.1, Number of unique lncRNAs: 1
# Contig: NW_020871785.1, Number of unique lncRNAs: 5
# Contig: NW_020871814.1, Number of unique lncRNAs: 1
# Contig: NW_020871817.1, Number of unique lncRNAs: 2
# Contig: NW_020871838.1, Number of unique lncRNAs: 1
# Contig: NW_020871841.1, Number of unique lncRNAs: 4
# Contig: NW_020871846.1, Number of unique lncRNAs: 4
# Contig: NW_020871867.1, Number of unique lncRNAs: 1
# Contig: NW_020871871.1, Number of unique lncRNAs: 3
# Contig: NW_020871878.1, Number of unique lncRNAs: 1
# Contig: NW_020871881.1, Number of unique lncRNAs: 1
# Contig: NW_020871924.1, Number of unique lncRNAs: 1
# Contig: NW_020871926.1, Number of unique lncRNAs: 1
# Contig: NW_020871955.1, Number of unique lncRNAs: 1
# Contig: NW_020871957.1, Number of unique lncRNAs: 1
# Contig: NW_020871967.1, Number of unique lncRNAs: 2
# Contig: NW_020871994.1, Number of unique lncRNAs: 1
# Contig: NW_020872013.1, Number of unique lncRNAs: 1
# Contig: NW_020872031.1, Number of unique lncRNAs: 1
# Contig: NW_020872045.1, Number of unique lncRNAs: 3
# Contig: NW_020872064.1, Number of unique lncRNAs: 1
# Contig: NW_020872066.1, Number of unique lncRNAs: 1
# Contig: NW_020872074.1, Number of unique lncRNAs: 1
# Contig: NW_020872085.1, Number of unique lncRNAs: 1
# Contig: NW_020872086.1, Number of unique lncRNAs: 1
# Contig: NW_020872088.1, Number of unique lncRNAs: 1
# Contig: NW_020872093.1, Number of unique lncRNAs: 1
# Contig: NW_020872096.1, Number of unique lncRNAs: 2
# Contig: NW_020872105.1, Number of unique lncRNAs: 1
# Contig: NW_020872108.1, Number of unique lncRNAs: 1
# Contig: NW_020872117.1, Number of unique lncRNAs: 1
# Contig: NW_020872145.1, Number of unique lncRNAs: 1
# Contig: NW_020872151.1, Number of unique lncRNAs: 3
# Contig: NW_020872161.1, Number of unique lncRNAs: 2
# Contig: NW_020872173.1, Number of unique lncRNAs: 1
# Contig: NW_020872174.1, Number of unique lncRNAs: 2
# Contig: NW_020872184.1, Number of unique lncRNAs: 1
# Contig: NW_020872185.1, Number of unique lncRNAs: 1
# Contig: NW_020872191.1, Number of unique lncRNAs: 2
# Contig: NW_020872193.1, Number of unique lncRNAs: 1
# Contig: NW_020872195.1, Number of unique lncRNAs: 1
# Contig: NW_020872203.1, Number of unique lncRNAs: 1
# Contig: NW_020872229.1, Number of unique lncRNAs: 3
# Contig: NW_020872244.1, Number of unique lncRNAs: 1
# Contig: NW_020872250.1, Number of unique lncRNAs: 1
# Contig: NW_020872260.1, Number of unique lncRNAs: 2
# Contig: NW_020872279.1, Number of unique lncRNAs: 1
# Contig: NW_020872284.1, Number of unique lncRNAs: 1
# Contig: NW_020872285.1, Number of unique lncRNAs: 1
# Contig: NW_020872287.1, Number of unique lncRNAs: 3
# Contig: NW_020872298.1, Number of unique lncRNAs: 1
# Contig: NW_020872315.1, Number of unique lncRNAs: 1
# Contig: NW_020872332.1, Number of unique lncRNAs: 2
# Contig: NW_020872340.1, Number of unique lncRNAs: 1
# Contig: NW_020872341.1, Number of unique lncRNAs: 1
# Contig: NW_020872348.1, Number of unique lncRNAs: 1
# Contig: NW_020872360.1, Number of unique lncRNAs: 1
# Contig: NW_020872368.1, Number of unique lncRNAs: 1
# Contig: NW_020872371.1, Number of unique lncRNAs: 1
# Contig: NW_020872389.1, Number of unique lncRNAs: 1
# Contig: NW_020872390.1, Number of unique lncRNAs: 1
# Contig: NW_020872398.1, Number of unique lncRNAs: 1
# Contig: NW_020872401.1, Number of unique lncRNAs: 3
# Contig: NW_020872403.1, Number of unique lncRNAs: 1
# Contig: NW_020872405.1, Number of unique lncRNAs: 1
# Contig: NW_020872407.1, Number of unique lncRNAs: 1
# Contig: NW_020872417.1, Number of unique lncRNAs: 1
# Contig: NW_020872420.1, Number of unique lncRNAs: 1
# Contig: NW_020872424.1, Number of unique lncRNAs: 2
# Contig: NW_020872432.1, Number of unique lncRNAs: 2
# Contig: NW_020872437.1, Number of unique lncRNAs: 4
# Contig: NW_020872442.1, Number of unique lncRNAs: 1
# Contig: NW_020872444.1, Number of unique lncRNAs: 2
# Contig: NW_020872445.1, Number of unique lncRNAs: 1
# Contig: NW_020872449.1, Number of unique lncRNAs: 1
# Contig: NW_020872450.1, Number of unique lncRNAs: 2
# Contig: NW_020872452.1, Number of unique lncRNAs: 1
# Contig: NW_020872455.1, Number of unique lncRNAs: 1
# Contig: NW_020872463.1, Number of unique lncRNAs: 1
# Contig: NW_020872467.1, Number of unique lncRNAs: 1
# Contig: NW_020872468.1, Number of unique lncRNAs: 1
# Contig: NW_020872476.1, Number of unique lncRNAs: 2
# Contig: NW_020872478.1, Number of unique lncRNAs: 2
# Contig: NW_020872479.1, Number of unique lncRNAs: 3
# Contig: NW_020872485.1, Number of unique lncRNAs: 1
# Contig: NW_020872488.1, Number of unique lncRNAs: 1
# Contig: NW_020872506.1, Number of unique lncRNAs: 2
# Contig: NW_020872508.1, Number of unique lncRNAs: 1
# Contig: NW_020872510.1, Number of unique lncRNAs: 1
# Contig: NW_020872515.1, Number of unique lncRNAs: 5
# Contig: NW_020872520.1, Number of unique lncRNAs: 2
# Contig: NW_020872521.1, Number of unique lncRNAs: 1
# Contig: NW_020872527.1, Number of unique lncRNAs: 1
# Contig: NW_020872530.1, Number of unique lncRNAs: 1
# Contig: NW_020872535.1, Number of unique lncRNAs: 3
# Contig: NW_020872540.1, Number of unique lncRNAs: 1
# Contig: NW_020872542.1, Number of unique lncRNAs: 1
# Contig: NW_020872544.1, Number of unique lncRNAs: 4
# Contig: NW_020872553.1, Number of unique lncRNAs: 1
# Contig: NW_020872556.1, Number of unique lncRNAs: 2
# Contig: NW_020872560.1, Number of unique lncRNAs: 2
# Contig: NW_020872561.1, Number of unique lncRNAs: 2
# Contig: NW_020872562.1, Number of unique lncRNAs: 1
# Contig: NW_020872563.1, Number of unique lncRNAs: 2
# Contig: NW_020872566.1, Number of unique lncRNAs: 1
# Contig: NW_020872567.1, Number of unique lncRNAs: 1
# Contig: NW_020872572.1, Number of unique lncRNAs: 1
# Contig: NW_020872590.1, Number of unique lncRNAs: 1
# Contig: NW_020872593.1, Number of unique lncRNAs: 1
# Contig: NW_020872596.1, Number of unique lncRNAs: 2
# Contig: NW_020872597.1, Number of unique lncRNAs: 1
# Contig: NW_020872600.1, Number of unique lncRNAs: 1
# Contig: NW_020872601.1, Number of unique lncRNAs: 1
# Contig: NW_020872603.1, Number of unique lncRNAs: 1
# Contig: NW_020872604.1, Number of unique lncRNAs: 1
# Contig: NW_020872610.1, Number of unique lncRNAs: 1
# Contig: NW_020872618.1, Number of unique lncRNAs: 1
# Contig: NW_020872619.1, Number of unique lncRNAs: 6
# Contig: NW_020872621.1, Number of unique lncRNAs: 1
# Contig: NW_020872622.1, Number of unique lncRNAs: 1
# Contig: NW_020872629.1, Number of unique lncRNAs: 2
# Contig: NW_020872632.1, Number of unique lncRNAs: 2
# Contig: NW_020872637.1, Number of unique lncRNAs: 2
# Contig: NW_020872639.1, Number of unique lncRNAs: 1
# Contig: NW_020872640.1, Number of unique lncRNAs: 2
# Contig: NW_020872641.1, Number of unique lncRNAs: 1
# Contig: NW_020872644.1, Number of unique lncRNAs: 1
# Contig: NW_020872646.1, Number of unique lncRNAs: 2
# Contig: NW_020872654.1, Number of unique lncRNAs: 4
# Contig: NW_020872656.1, Number of unique lncRNAs: 1
# Contig: NW_020872659.1, Number of unique lncRNAs: 1
# Contig: NW_020872660.1, Number of unique lncRNAs: 2
# Contig: NW_020872667.1, Number of unique lncRNAs: 3
# Contig: NW_020872674.1, Number of unique lncRNAs: 3
# Contig: NW_020872677.1, Number of unique lncRNAs: 3
# Contig: NW_020872683.1, Number of unique lncRNAs: 1
# Contig: NW_020872686.1, Number of unique lncRNAs: 1
# Contig: NW_020872687.1, Number of unique lncRNAs: 1
# Contig: NW_020872690.1, Number of unique lncRNAs: 2
# Contig: NW_020872692.1, Number of unique lncRNAs: 6
# Contig: NW_020872693.1, Number of unique lncRNAs: 1
# Contig: NW_020872694.1, Number of unique lncRNAs: 1
# Contig: NW_020872695.1, Number of unique lncRNAs: 1
# Contig: NW_020872696.1, Number of unique lncRNAs: 2
# Contig: NW_020872701.1, Number of unique lncRNAs: 3
# Contig: NW_020872705.1, Number of unique lncRNAs: 1
# Contig: NW_020872715.1, Number of unique lncRNAs: 1
# Contig: NW_020872719.1, Number of unique lncRNAs: 1
# Contig: NW_020872720.1, Number of unique lncRNAs: 1
# Contig: NW_020872726.1, Number of unique lncRNAs: 1
# Contig: NW_020872727.1, Number of unique lncRNAs: 1
# Contig: NW_020872734.1, Number of unique lncRNAs: 7
# Contig: NW_020872741.1, Number of unique lncRNAs: 2
# Contig: NW_020872745.1, Number of unique lncRNAs: 1
# Contig: NW_020872753.1, Number of unique lncRNAs: 1
# Contig: NW_020872759.1, Number of unique lncRNAs: 8
# Contig: NW_020872760.1, Number of unique lncRNAs: 1
# Contig: NW_020872761.1, Number of unique lncRNAs: 2
# Contig: NW_020872767.1, Number of unique lncRNAs: 3
# Contig: NW_020872770.1, Number of unique lncRNAs: 1
# Contig: NW_020872772.1, Number of unique lncRNAs: 1
# Contig: NW_020872774.1, Number of unique lncRNAs: 1
# Contig: NW_020872775.1, Number of unique lncRNAs: 1
# Contig: NW_020872788.1, Number of unique lncRNAs: 2
# Contig: NW_020872789.1, Number of unique lncRNAs: 1
# Contig: NW_020872794.1, Number of unique lncRNAs: 1
# Contig: NW_020872797.1, Number of unique lncRNAs: 3
# Contig: NW_020872804.1, Number of unique lncRNAs: 2
# Contig: NW_020872808.1, Number of unique lncRNAs: 9
# Contig: NW_020872814.1, Number of unique lncRNAs: 2
# Contig: NW_020872825.1, Number of unique lncRNAs: 1
# Contig: NW_020872826.1, Number of unique lncRNAs: 1
# Contig: NW_020872829.1, Number of unique lncRNAs: 6
# Contig: NW_020872836.1, Number of unique lncRNAs: 1
# Contig: NW_020872837.1, Number of unique lncRNAs: 2
# Contig: NW_020872838.1, Number of unique lncRNAs: 1
# Contig: NW_020872843.1, Number of unique lncRNAs: 1
# Contig: NW_020872848.1, Number of unique lncRNAs: 1
# Contig: NW_020872850.1, Number of unique lncRNAs: 1
# Contig: NW_020872851.1, Number of unique lncRNAs: 3
# Contig: NW_020872852.1, Number of unique lncRNAs: 1
# Contig: NW_020872855.1, Number of unique lncRNAs: 2
# Contig: NW_020872861.1, Number of unique lncRNAs: 1
# Contig: NW_020872862.1, Number of unique lncRNAs: 1
# Contig: NW_020872864.1, Number of unique lncRNAs: 19
# Contig: NW_020872866.1, Number of unique lncRNAs: 1
# Contig: NW_020872870.1, Number of unique lncRNAs: 5
# Contig: NW_020872883.1, Number of unique lncRNAs: 1
# Contig: NW_020872886.1, Number of unique lncRNAs: 2
# Contig: NW_020872893.1, Number of unique lncRNAs: 3
# Contig: NW_020872894.1, Number of unique lncRNAs: 1
# Contig: NW_020872899.1, Number of unique lncRNAs: 2
# Contig: NW_020872903.1, Number of unique lncRNAs: 1
# Contig: NW_020872907.1, Number of unique lncRNAs: 1
# Contig: NW_020872911.1, Number of unique lncRNAs: 1
# Contig: NW_020872932.1, Number of unique lncRNAs: 1
# Contig: NW_020872933.1, Number of unique lncRNAs: 2
# Contig: NW_020872936.1, Number of unique lncRNAs: 1
# Contig: NW_020872949.1, Number of unique lncRNAs: 1
# Contig: NW_020872953.1, Number of unique lncRNAs: 1
# Contig: NW_020872954.1, Number of unique lncRNAs: 1
# Contig: NW_020872955.1, Number of unique lncRNAs: 1
# Contig: NW_020872956.1, Number of unique lncRNAs: 1
# Contig: NW_020872958.1, Number of unique lncRNAs: 2
# Contig: NW_020872964.1, Number of unique lncRNAs: 7
# The total number of long non-coding RNAs matches the expected: 2,028

# %%
# load the IDs in a .txt file as a list
ids_interes = set()
with open('true_Up_muscle_lncRNAs.txt', 'r') as f_ids:
    for line in f_ids:
        ids_interes.add(line.strip())

print("IDs de interés cargados:", ids_interes)  # Mensaje de depuración

# Encontrar en qué contigs están presentes los IDs de interés
contigs_interes = defaultdict(list)

for contig_id, features in contigs.items():
    for feature in features:
        if feature['type'] == 'lnc_RNA':
            metadata_dict = feature['metadata']
            gene_id = metadata_dict.get('ID', 'Unknown')
            if gene_id.startswith('rna-'):
                gene_id = gene_id[4:]  # Remover el prefijo 'rna-'
            if gene_id in ids_interes:
                contigs_interes[gene_id].append(contig_id)

# Mostrar los resultados
# for gene_id, contig_list in contigs_interes.items():
#     print(f"ID: {gene_id}, Contigs: {contig_list}")
# Out:
# IDs de interés cargados: {'XR_003476908.1', 'XR_003476489.1', 'XR_003477015.1', 'XR_003477013.1', 'XR_003476309.1', 'XR_003475609.1', 'XR_003476045.1', 'XR_003477469.1', 'XR_003477805.1', 'XR_003476046.1', 'XR_003476044.1', 'XR_003477476.1'}
# ID: XR_003475609.1, Contigs: ['NW_020868904.1']
# ID: XR_003476046.1, Contigs: ['NW_020869391.1']
# ID: XR_003476045.1, Contigs: ['NW_020869391.1']
# ID: XR_003476044.1, Contigs: ['NW_020869391.1']
# ID: XR_003476309.1, Contigs: ['NW_020869751.1']
# ID: XR_003476489.1, Contigs: ['NW_020869983.1']
# ID: XR_003476908.1, Contigs: ['NW_020870418.1']
# ID: XR_003477013.1, Contigs: ['NW_020870513.1']
# ID: XR_003477015.1, Contigs: ['NW_020870513.1']
# ID: XR_003477469.1, Contigs: ['NW_020871061.1']
# ID: XR_003477476.1, Contigs: ['NW_020871071.1']
# ID: XR_003477805.1, Contigs: ['NW_020872368.1']

# %%
# define funciton to search for neighbouring mRNAs 
def find_mRNA_neighbors(features, lncRNA_index):
    """
    search neighbouring mRNAs for a given lncRNA
    return upstream and downstream mRNA indices if they exist
    """
    upstream_mRNA = downstream_mRNA = None
    lncRNA = features[lncRNA_index]

    for i, feature in enumerate(features):
        if feature['type'] == 'mRNA':
            if feature['end'] < lncRNA['start']:  # upstream mRNA
                if upstream_mRNA is None or features[upstream_mRNA]['end'] < feature['end']:
                    upstream_mRNA = i
            elif feature['start'] > lncRNA['end']:  # downstream mRNA
                if downstream_mRNA is None or features[downstream_mRNA]['start'] > feature['start']:
                    downstream_mRNA = i

    return upstream_mRNA, downstream_mRNA

# search for neighbouring mRNAs for a interest given IDs
for gene_id in ids_interes:
    for contig_id in contigs_interes[gene_id]:
        features = contigs[contig_id]
        for i, feature in enumerate(features):
            if feature['type'] == 'lnc_RNA' and feature['metadata'].get('ID', '').endswith(gene_id):
                upstream_mRNA_idx, downstream_mRNA_idx = find_mRNA_neighbors(features, i)
                if upstream_mRNA_idx is not None and downstream_mRNA_idx is not None:
                    upstream_mRNA = features[upstream_mRNA_idx]
                    downstream_mRNA = features[downstream_mRNA_idx]

                    upstream_mRNA_id = upstream_mRNA['metadata'].get('ID', 'Unknown')
                    downstream_mRNA_id = downstream_mRNA['metadata'].get('ID', 'Unknown')

                    print(f"lncRNA {gene_id} in contig {contig_id}:")
                    print(f"  Upstream mRNA: {upstream_mRNA_id}")
                    print(f"  Downstream mRNA: {downstream_mRNA_id}")
                    
                    # check and report overlappings
                    if feature['start'] <= upstream_mRNA['end']:
                        print(f"  Overlaps with upstream mRNA: {upstream_mRNA_id}")
                    if feature['end'] >= downstream_mRNA['start']:
                        print(f"  Overlaps with downstream mRNA: {downstream_mRNA_id}")
                    print() 
                else:
                    if upstream_mRNA_idx is None:
                        print(f"  No upstream mRNA found for lncRNA {gene_id} in contig {contig_id}\n")
                    if downstream_mRNA_idx is None:
                        print(f"  No downstream mRNA found for lncRNA {gene_id} in contig {contig_id}\n")
# Out:
# lncRNA XR_003476908.1 in contig NW_020870418.1:
#   Upstream mRNA: rna-XM_027370782.1
#   Downstream mRNA: rna-XM_027370783.1
#
#   No upstream mRNA found for lncRNA XR_003476489.1 in contig NW_020869983.1
#
# lncRNA XR_003477015.1 in contig NW_020870513.1:
#   Upstream mRNA: rna-XM_027371589.1
#   Downstream mRNA: rna-XM_027371590.1
#
# lncRNA XR_003477013.1 in contig NW_020870513.1:
#   Upstream mRNA: rna-XM_027371589.1
#   Downstream mRNA: rna-XM_027371590.1
#
#   No upstream mRNA found for lncRNA XR_003476309.1 in contig NW_020869751.1
#
# lncRNA XR_003475609.1 in contig NW_020868904.1:
#   Upstream mRNA: rna-XM_027355539.1
#   Downstream mRNA: rna-XM_027355540.1
#
# lncRNA XR_003476045.1 in contig NW_020869391.1:
#   Upstream mRNA: rna-XM_027360592.1
#   Downstream mRNA: rna-XM_027360584.1
#
# lncRNA XR_003477469.1 in contig NW_020871061.1:
#   Upstream mRNA: rna-XM_027376763.1
#   Downstream mRNA: rna-XM_027376772.1
#
# lncRNA XR_003477805.1 in contig NW_020872368.1:
#   Upstream mRNA: rna-XM_027381290.1
#   Downstream mRNA: rna-XM_027381264.1
#
# lncRNA XR_003476046.1 in contig NW_020869391.1:
#   Upstream mRNA: rna-XM_027360592.1
#   Downstream mRNA: rna-XM_027360584.1
#
# lncRNA XR_003476044.1 in contig NW_020869391.1:
#   Upstream mRNA: rna-XM_027360592.1
#   Downstream mRNA: rna-XM_027360584.1
#
# lncRNA XR_003477476.1 in contig NW_020871071.1:
#   Upstream mRNA: rna-XM_027376868.1
#   Downstream mRNA: rna-XM_027376856.1

# %%
################ Calculate percentage of lncRNAs with neighboring mRNAs ################
def find_mRNA_neighbors(features, lncRNA_index):
    """
    search neighbouring mRNAs for a given lncRNA
    return upstream and downstream mRNA indices if they exist
    """
    upstream_mRNA = downstream_mRNA = None
    lncRNA = features[lncRNA_index]

    for i, feature in enumerate(features):
        if feature['type'] == 'mRNA':
            if feature['end'] < lncRNA['start']:  # upstream mRNA
                if upstream_mRNA is None or features[upstream_mRNA]['end'] < feature['end']:
                    upstream_mRNA = i
            elif feature['start'] > lncRNA['end']:  # downstream mRNA
                if downstream_mRNA is None or features[downstream_mRNA]['start'] > feature['start']:
                    downstream_mRNA = i

    return upstream_mRNA, downstream_mRNA

# percentage of lncRNAs with neighboring mRNAs
total_lncRNAs = 0
flanked_lncRNAs = 0

for contig_id, features in contigs.items():
    for i, feature in enumerate(features):
        if feature['type'] == 'lnc_RNA':
            total_lncRNAs += 1
            upstream_mRNA_idx, downstream_mRNA_idx = find_mRNA_neighbors(features, i)
            if upstream_mRNA_idx is not None and downstream_mRNA_idx is not None:
                flanked_lncRNAs += 1

# calculate
if total_lncRNAs > 0:
    percentage_flanked = (flanked_lncRNAs / total_lncRNAs) * 100
    print(f"Total lncRNAs: {total_lncRNAs}")
    print(f"Flanked lncRNAs: {flanked_lncRNAs}")
    print(f"Percentage of flanked lncRNAs: {percentage_flanked:.2f}%")
else:
    print("No lncRNAs found.")
# Out:
# Total lncRNAs: 2028
# Flanked lncRNAs: 1512
# Percentage of flanked lncRNAs: 74.56%

# %%
################ calculate distances between up/downstream ################
def find_mRNA_neighbors(features, lncRNA_index):
    """
    search neighbouring mRNAs for a given lncRNA
    return upstream and downstream mRNA indices if they exist
    """
    upstream_mRNA = downstream_mRNA = None
    lncRNA = features[lncRNA_index]

    for i, feature in enumerate(features):
        if feature['type'] == 'mRNA':
            if feature['end'] < lncRNA['start']:  # upstream mRNA
                if upstream_mRNA is None or features[upstream_mRNA]['end'] < feature['end']:
                    upstream_mRNA = i
            elif feature['start'] > lncRNA['end']:  # downstream mRNA
                if downstream_mRNA is None or features[downstream_mRNA]['start'] > feature['start']:
                    downstream_mRNA = i

    return upstream_mRNA, downstream_mRNA

# distances calculations
total_lncRNAs = 0
flanked_lncRNAs = 0
upstream_distances = []
downstream_distances = []

for contig_id, features in contigs.items():
    for i, feature in enumerate(features):
        if feature['type'] == 'lnc_RNA':
            total_lncRNAs += 1
            upstream_mRNA_idx, downstream_mRNA_idx = find_mRNA_neighbors(features, i)
            if upstream_mRNA_idx is not None and downstream_mRNA_idx is not None:
                flanked_lncRNAs += 1
                lncRNA = feature 
                upstream_mRNA = features[upstream_mRNA_idx]
                downstream_mRNA = features[downstream_mRNA_idx]

                upstream_distance = lncRNA['start'] - upstream_mRNA['end']
                downstream_distance = downstream_mRNA['start'] - lncRNA['end']
                upstream_distances.append(upstream_distance)
                downstream_distances.append(downstream_distance)

# disances mean
if upstream_distances:
    avg_upstream_distance = sum(upstream_distances) / len(upstream_distances) / 1000  # to Kb
else:
    avg_upstream_distance = 0

if downstream_distances:
    avg_downstream_distance = sum(downstream_distances) / len(downstream_distances) / 1000  # to Kb
else:
    avg_downstream_distance = 0

# print results
print(f"Total lncRNAs: {total_lncRNAs}")
print(f"Flanked lncRNAs: {flanked_lncRNAs}")
print(f"Percentage of flanked lncRNAs: {flanked_lncRNAs / total_lncRNAs * 100:.2f}%")
print(f"Average upstream distance: {avg_upstream_distance:.2f} kb")
print(f"Average downstream distance: {avg_downstream_distance:.2f} kb")
# Out:
# Total lncRNAs: 2028
# Flanked lncRNAs: 1512
# Percentage of flanked lncRNAs: 74.56%
# Average upstream distance: 34.35 kb
# Average downstream distance: 35.36 kb

# %%
########################### MAIN FUNCTION ###########################
def find_mRNA_neighbors(features, lncRNA_index):
    """
    search neighbouring mRNAs for a given lncRNA
    return upstream and downstream mRNA indices if they exist
    """
    upstream_mRNA = downstream_mRNA = None
    lncRNA = features[lncRNA_index]

    for i, feature in enumerate(features):
        if feature['type'] == 'mRNA':
            if feature['end'] < lncRNA['start']:  # upstream mRNA
                if upstream_mRNA is None or features[upstream_mRNA]['end'] < feature['end']:
                    upstream_mRNA = i
            elif feature['start'] > lncRNA['end']:  # downstream mRNA
                if downstream_mRNA is None or features[downstream_mRNA]['start'] > feature['start']:
                    downstream_mRNA = i

    return upstream_mRNA, downstream_mRNA

# distances calculations
lncRNA_distances = []

for gene_id in ids_interes:
    for contig_id in contigs_interes[gene_id]:
        features = contigs[contig_id]
        for i, feature in enumerate(features):
            if feature['type'] == 'lnc_RNA' and feature['metadata'].get('ID', '').endswith(gene_id):
                upstream_mRNA_idx, downstream_mRNA_idx = find_mRNA_neighbors(features, i)
                if upstream_mRNA_idx is not None and downstream_mRNA_idx is not None:
                    upstream_mRNA = features[upstream_mRNA_idx]
                    downstream_mRNA = features[downstream_mRNA_idx]

                    upstream_distance = feature['start'] - upstream_mRNA['end']
                    downstream_distance = downstream_mRNA['start'] - feature['end']
                    lncRNA_distances.append({
                        'lncRNA_id': gene_id,
                        'contig_id': contig_id,
                        'upstream_mRNA_id': upstream_mRNA['metadata'].get('ID', 'Unknown'),
                        'downstream_mRNA_id': downstream_mRNA['metadata'].get('ID', 'Unknown'),
                        'upstream_distance': upstream_distance,
                        'downstream_distance': downstream_distance
                    })

# print results
for entry in lncRNA_distances:
    print(f"lncRNA ID: {entry['lncRNA_id']} in contig {entry['contig_id']}:")
    print(f"  Upstream mRNA ID: {entry['upstream_mRNA_id']}, Distance: {entry['upstream_distance']} bases")
    print(f"  Downstream mRNA ID: {entry['downstream_mRNA_id']}, Distance: {entry['downstream_distance']} bases")
    print()
# Out:
# lncRNA ID: XR_003476908.1 in contig NW_020870418.1:
#   Upstream mRNA ID: rna-XM_027370782.1, Distance: 12358 bases
#   Downstream mRNA ID: rna-XM_027370783.1, Distance: 2656 bases
#
# lncRNA ID: XR_003477015.1 in contig NW_020870513.1:
#   Upstream mRNA ID: rna-XM_027371589.1, Distance: 33033 bases
#   Downstream mRNA ID: rna-XM_027371590.1, Distance: 72507 bases
#
# lncRNA ID: XR_003477013.1 in contig NW_020870513.1:
#   Upstream mRNA ID: rna-XM_027371589.1, Distance: 29098 bases
#   Downstream mRNA ID: rna-XM_027371590.1, Distance: 76338 bases
#
# lncRNA ID: XR_003475609.1 in contig NW_020868904.1:
#   Upstream mRNA ID: rna-XM_027355539.1, Distance: 50245 bases
#   Downstream mRNA ID: rna-XM_027355540.1, Distance: 111264 bases
#
# lncRNA ID: XR_003476045.1 in contig NW_020869391.1:
#   Upstream mRNA ID: rna-XM_027360592.1, Distance: 3674 bases
#   Downstream mRNA ID: rna-XM_027360584.1, Distance: 28121 bases
#
# lncRNA ID: XR_003477469.1 in contig NW_020871061.1:
#   Upstream mRNA ID: rna-XM_027376763.1, Distance: 84 bases
#   Downstream mRNA ID: rna-XM_027376772.1, Distance: 83430 bases
#
# lncRNA ID: XR_003477805.1 in contig NW_020872368.1:
#   Upstream mRNA ID: rna-XM_027381290.1, Distance: 12073 bases
#   Downstream mRNA ID: rna-XM_027381264.1, Distance: 107656 bases
#
# lncRNA ID: XR_003476046.1 in contig NW_020869391.1:
#   Upstream mRNA ID: rna-XM_027360592.1, Distance: 3674 bases
#   Downstream mRNA ID: rna-XM_027360584.1, Distance: 28056 bases
#
# lncRNA ID: XR_003476044.1 in contig NW_020869391.1:
#   Upstream mRNA ID: rna-XM_027360592.1, Distance: 3674 bases
#   Downstream mRNA ID: rna-XM_027360584.1, Distance: 28127 bases
#
# lncRNA ID: XR_003477476.1 in contig NW_020871071.1:
#   Upstream mRNA ID: rna-XM_027376868.1, Distance: 10422 bases
#   Downstream mRNA ID: rna-XM_027376856.1, Distance: 133485 bases
